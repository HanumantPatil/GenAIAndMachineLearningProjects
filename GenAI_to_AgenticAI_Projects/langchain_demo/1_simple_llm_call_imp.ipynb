# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="ornith:9b", temperature=0.7)

llm.invoke("Who was the first person to go to the moon?")
# Out:
# AIMessage(content='**Neil Armstrong** was the first person to walk on the Moon. He stepped onto the lunar surface during NASA\'s **Apollo 11 mission** on July 20, 1969, famously declaring: *"That\'s one small step for [a] man, one giant leap for mankind."*', additional_kwargs={}, response_metadata={'model': 'ornith:9b', 'created_at': '2026-07-23T02:20:28.0765153Z', 'done': True, 'done_reason': 'stop', 'total_duration': 63132474600, 'load_duration': 387937300, 'prompt_eval_count': 79, 'prompt_eval_duration': 4322293000, 'eval_count': 177, 'eval_duration': 58416012000, 'logprobs': None, 'model_name': 'ornith:9b', 'model_provider': 'ollama'}, id='lc_run--019f8cc5-3f8e-7df2-95f1-bef2588636b5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 79, 'output_tokens': 177, 'total_tokens': 256})

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="openai/gpt-oss-120b", temperature=0.7)

llm.invoke("Who was the first person to go to the moon?")
